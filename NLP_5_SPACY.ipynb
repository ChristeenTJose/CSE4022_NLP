# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristeenTJose/CSE4022_NLP/blob/master/NLP_5_SPACY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image 1.png](data:image/png;base64,...)

# %%
import spacy

# %% [markdown]
# #Load the Model
#
# ## en_core_web_sm
# English multi-task CNN trained on OntoNotes. Assigns context-specific token vectors, POS tags, dependency parse and named entities.
#
# ## en_core_web_md
# English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl. Assigns word vectors, POS tags, dependency parse and named entities.
#
# ## en_core_web_lg
# English multi-task CNN trained on OntoNotes, with GloVe vectors trained on Common Crawl. Assigns word vectors, POS tags, dependency parses and named entities.

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# # NER

# %%
example ='Steven Paul Jobs was an American business magnate, industrial designer, investor, and media proprietor.'
example +='He was the chairman, chief executive officer (CEO), and co-founder of Apple Inc., '
example +='the chairman and majority shareholder of Pixar, a member of The Walt Disney Company\'s' 
example +='board of directors following its acquisition of Pixar, and the founder, chairman, and CEO of NeXT.'
example +='Jobs is widely recognized as a pioneer of the personal computer revolution of the 1970s and 1980s,'
example +='along with Apple co-founder Steve Wozniak.'

# %%
doc=nlp(example)

# %%
for ent in doc.ents:
  print(ent.text,ent.label_)
# Out:
# Steven Paul Jobs PERSON
# American NORP
# Apple Inc. ORG
# Pixar ORG
# The Walt Disney ORG
# Pixar ORG
# NeXT.Jobs GPE
# 1970s DATE
# 1980s DATE
# Apple ORG
# Steve Wozniak PERSON

# %% [markdown]
# # Querying

# %%
locs = [('Omnicom', 'IN', 'New York'),('DDB Needham', 'IN', 'New York'), ('Kaplan Thaler Group', 'IN', 'New York'),('BBDO South', 'IN', 'Atlanta'), ('Georgia-Pacific', 'IN', 'Atlanta')]

# %%
query = [e1 for (e1, rel, e2) in locs if e2=='Atlanta']

# %%
query
# Out:
# ['BBDO South', 'Georgia-Pacific']
